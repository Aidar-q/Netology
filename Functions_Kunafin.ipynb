# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}
def document_find():
    found = False
    num = input("Введите номер документа:")
    for doc in documents:
        if "number" in doc.keys() and doc["number"] == num:
            print(f'Владелец документа: ', doc["name"])
            found = True
    if not found:
            print("Документ не найден в базе")
document_find()

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': ['']
}
def directories_find():
    found = False
    num = input("Введите номер документа: ")
    for x in list(directories.items()):
        if num in x[1]:
            print(f'Документ хранится на полке: ', x[0])
            found = True
    if not found:
        print("Документ не найден в базе")
directories_find()

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': ['']
}
def full_info():
        for x in documents:
            for z in list(directories.items()):
                if x['number'] in z[1]:
                    print(f'№:',x['number']+',', 'тип: '+x['type']+',', 'владелец: '+x['name']+',','полка хранения:',z[0])
full_info()

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': ['']
}
def directories_app():
    f = False
    num = input("Введите номер полки: ")
    for d in directories.items():
        if num in d[0]:
            print(f'Такая полка уже существует. Текущий перечень полок:', list(directories.keys()))
            f = True
    if not f:
        directories.setdefault(num,[''])
        print(f'Полка добавлена. Текущий перечень полок:', list(directories.keys()))
directories_app()

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': ['']
}
def directories_rem():
    f = False
    num = input("Введите номер полки: ")
    if num in directories:
        for a in directories[num]:
            if len(a) == 0:
                del directories[num]
                print(f'Полка удалена. Текущий перечень полок:', list(directories.keys()))
                f = True
            if not f:
                print(f'На полке есть документы, удалите их перед удалением полки. Текущий перечень полок:', list(directories.keys()))
    else:
        print(f'Такой полки не существует. Текущий перечень полок:', list(directories.keys()))
directories_rem()

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': ['']
}
def main(documents, directories):
    while True:
        com = input('Введите команду')
        if com == 'p':
            num = input("Введите номер документа: ")
            print(document_find(num))
        elif com == 's':
            num = input("Введите номер документа: ")
            print(directories_find(num))
        elif com == 'l':
            print(full_info(documents, directories))
        elif com == 'as':
            num = input("Введите номер полки: ")
            print(directories_app(number))
        elif com == 'ds':
            num = input("Введите номер полки: ")
            print(directories_rem(num))
        elif com == 'q':
            break
main(documents, directories)
